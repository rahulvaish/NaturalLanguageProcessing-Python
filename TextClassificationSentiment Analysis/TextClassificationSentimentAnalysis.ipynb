# %%
import pandas as pd
import seaborn as sns

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
nlp = spacy.load('en')
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.metrics import accuracy_score 
from sklearn.base import TransformerMixin 
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC

# %%
df = pd.read_csv('C:/Users/Lenovo/Desktop/IPY/SentimentDataSetCSV.csv')

# %%
# Length and Shape 
df.shape
# Out:
# (2997, 4)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Message', 'Target'], dtype='object')

# %%
df = df.drop(columns=['Unnamed: 0', 'Unnamed: 1'])

# %%
df.shape
# Out:
# (2997, 2)

# %%
# Checking for Missing Values
df.isnull().sum()
# Out:
# Message    0
# Target     0
# dtype: int64

# %%
# Features and Labels
X = df['Message']
ylabels = df['Target']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, ylabels, test_size=0.2)

# %%
# Create the  pipeline to clean, tokenize, vectorize, and classify 
pipe = Pipeline([("cleaner", predictors()),
                 ('vectorizer', vectorizer),
                 ('classifier', classifier)])

# %%
# Fit our data
pipe.fit(X_train,y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('cleaner', <__main__.predictors object at 0x000001219CF03588>), ('vectorizer', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#       ...ax_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0))])

# %%
# Predicting with a test dataset
sample_prediction = pipe.predict(X_test)

# %%
# Prediction Results
# 1 = Positive review
# 0 = Negative review
for (sample,pred) in zip(X_test,sample_prediction):
    print(sample,"Prediction=>",pred)
# Out:
# The movie is terribly boring in places.   Prediction=> 0
# Lordy, the Khao Soi is a dish that is not to be missed for curry lovers! Prediction=> 0
# Very Displeased. Prediction=> 0
# The sets (especially designed to work with the camera) are amazing....stylized, beautiful and effective.   Prediction=> 1
# They refuse to refund or replace. Prediction=> 0
# Internet is excrutiatingly slow. Prediction=> 0
# Waitress was a little slow in service. Prediction=> 0
# the worst phone from samsung...crap..... this crappy Samsung E715.. is the worst i have ever seeen. Prediction=> 0
# 2 times - Very Bad Customer Service ! Prediction=> 0
# The staff are great, the ambiance is great. Prediction=> 1
# Soggy and not good. Prediction=> 1
# Even if you love bad movies, do not watch this movie.   Prediction=> 1
# Service was slow and not attentive. Prediction=> 0
# As a European, the movie is a nice throwback to my time as a student in the 1980's and the experiences I had living abroad and interacting with other nationalities, although the circumstances were slightly different.   Prediction=> 1
# We literally sat there for 20 minutes with no one asking to take our order. Prediction=> 0
# What SHOULD have been a hilarious, yummy Christmas Eve dinner to remember was the biggest fail of the entire trip for us. Prediction=> 1
# The grilled chicken was so tender and yellow from the saffron seasoning. Prediction=> 1
# It actually turned out to be pretty decent as far as B-list horror/suspense films go.   Prediction=> 1
# Even worse than Ticker!   Prediction=> 0
# The bartender was also nice. Prediction=> 1
# I won't be back. Prediction=> 0
# Then, as if I hadn't wasted enough of my life there, they poured salt in the wound by drawing out the time it took to bring the check. Prediction=> 0
# The basic premise is wasted since it is sidelined by the inexplicable focus on the documentary crew.   Prediction=> 0
# These headphones were a great find - and I think they are perhaps the best purchase I've made in the last several years - seriously. Prediction=> 0
# This film (and I use that word loosely) is an insult to the movie-going public.   Prediction=> 1
# It's a feel-good film and that's how I felt when I came out of the cinema!   Prediction=> 1
# I highly recommend this movie for anyone interested in art, poetry, theater, politics, or Japanese history.   Prediction=> 1
# The acting is terrible, and the writing is worse.   Prediction=> 0
# Still it's quite interesting and entertaining to follow.   Prediction=> 1
# poor quality and service. Prediction=> 0
# Both actors truly understand and become their particular character, delivering a convincing, sincere performance.   Prediction=> 0
# Everything about it is just bad.   Prediction=> 0
# Not good by any stretch of the imagination. Prediction=> 1
# The soundtrack wasn't terrible, either.   Prediction=> 0
# That's right....the red velvet cake.....ohhh this stuff is so good. Prediction=> 1
# This is the first phone I've had that has been so cheaply made. Prediction=> 0
# They dropped more than the ball. Prediction=> 0
# It also had a new problem. Prediction=> 0
# Much more interesting, more action, more suspense, and less of the unneeded controversy.   Prediction=> 0
# Earbud piece breaks easily. Prediction=> 0
# Service was good and the company was better! Prediction=> 1
# I still maintain that monkeys shouldn't make headphones, we just obviously don't share enough DNA to copy the design over to humans. Prediction=> 0
# The acting sucked.   Prediction=> 0
# The burger is good beef, cooked just right. Prediction=> 1
# I also didn't like the on button, it felt like it would crack with use. Prediction=> 1
# The Foreigner is not worth one second of your time.   Prediction=> 0
# I love the look and feel of Samsung flipphones. Prediction=> 1
# Unfortunately the ability to actually know you are receiving a call is a rather important feature and this phone is pitiful in that respect. Prediction=> 0
# If there is a wind, it is completely useless. Prediction=> 0
# End of Days is one of the worst big-budget action movies I've ever seen.   Prediction=> 0
# Not much seafood and like 5 strings of pasta at the bottom. Prediction=> 1
# Editing: The editing of this film was phenomenal in my opinion.   Prediction=> 1
# Food was great and so was the serivce! Prediction=> 1
# horrible, had to switch 3 times. Prediction=> 0
# So I had to take the battery out of the phone put it all back together and then restart it. Prediction=> 0
# I would highly recommend this. Prediction=> 1
# Beautiful styling though. Prediction=> 1
# I don't think we'll be going back anytime soon. Prediction=> 0
# Mediocre food. Prediction=> 0
# Bland... Not a liking this place for a number of reasons and I don't want to waste time on bad reviewing.. I'll leave it at that... Prediction=> 0
# It ranks highly as a great noir-crime-drama, incredible performances by Belmondo and Lino Ventura.   Prediction=> 1
# Excellent sound quality. Prediction=> 1
# I was seated immediately. Prediction=> 0
# I came out of it feeling angry.   Prediction=> 0
# I have had mine for about a year and this Christmas I bought some for the rest of the family. Prediction=> 1
# When I first watched this movie, in the 80s, I loved it.   Prediction=> 1
# The atmosphere is modern and hip, while maintaining a touch of coziness. Prediction=> 1
# If you look for authentic Thai food, go else where. Prediction=> 0
# i'm glad i found this product on amazon it is hard to find, it wasn't high priced. Prediction=> 1
# This is definitely a cult classic well worth viewing and sharing with others.   Prediction=> 1
# Another note about this phone's appearance is that it really looks rather bland, especially in the all black model. Prediction=> 0
# Worse, there's an incredibly weak sub-plot thrown in that follows a little band of latter-day Mansonites as they go after a reporter who's working on a story on the anniversary of the killings.   Prediction=> 0
# Their frozen margaritas are WAY too sugary for my taste. Prediction=> 0
# The guy who said he's had better dialogue with his potted plants has it right.   Prediction=> 1
# After the disappointing dinner we went elsewhere for dessert. Prediction=> 0
# It's like a bad two hour TV movie.   Prediction=> 0
# Both of them were truly unbelievably good, and I am so glad we went back. Prediction=> 1
# Very very fun chef. Prediction=> 1
# It was so bad, I had lost the heart to finish it. Prediction=> 0
# Maybe it's just their Vegetarian fare, but I've been twice and I thought it was average at best. Prediction=> 0
# The keyboard is a nice compromise between a full QWERTY and the basic cell phone number keypad. Prediction=> 1
# I literally vomited while watching this film.   Prediction=> 1
# How stupid is that? Prediction=> 0
# Don't buy this product. Prediction=> 0
# It was a huge awkward 1.5lb piece of cow that was 3/4ths gristle and fat. Prediction=> 0
# He also came back to check on us regularly, excellent service. Prediction=> 1
# I am glad I purchased it. Prediction=> 0
# Simply beautiful.   Prediction=> 1
# A fantastic neighborhood gem !!! Prediction=> 1
# We made the drive all the way from North Scottsdale... and I was not one bit disappointed! Prediction=> 0
# Love this place, hits the spot when I want something healthy but not lacking in quantity or flavor. Prediction=> 1
# T-Mobile has the best customer service anywhere. Prediction=> 0
# The cinematography is simply stunning (to say the least) and the fx are nothing if not state-of-the-art.   Prediction=> 1
# If good intentions made a film great, then this film might be one of the greatest films ever made.   Prediction=> 1
# It's so stupid to have to keep buying new chargers, car chargers, cradles, headphones and car kits every time a new phone comes out. Prediction=> 0
# Best tacos in town by far!! Prediction=> 1
# What a waste. Prediction=> 0
# Third, the cheese on my friend's burger was cold. Prediction=> 0
# The calls drop, the phone comes on and off at will, the screen goes black and the worst of all it stops ringing intermittently. Prediction=> 0
# This is a stunning movie.   Prediction=> 1
# It kept getting worse and worse so now I'm officially done. Prediction=> 0
# first of all, there are enough racial stereotypes and racial jokes to offend everyone.   Prediction=> 0
# Jawbone Era is awesome too! Prediction=> 1
# Never heard of any of them except Cole who was totally unbelievable in the part.   Prediction=> 0
# No real improvement. Prediction=> 0
# Try them in the airport to experience some tasty food and speedy, friendly service. Prediction=> 1
# This movie is great--especially if you enjoy visual arts.   Prediction=> 1
# The concert sequences just sucked.   Prediction=> 0
# This phone is very fast with sending any kind of messages and web browsing is significantly faster than previous phones i have used. Prediction=> 1
# It was horrendous.   Prediction=> 0
# It is a joy to use. Prediction=> 1
# My first visit to Hiro was a delight! Prediction=> 1
# The acting from all involved and that includes those like Shatner and Nimoy is bad and washed out and making them seem as old as they look in real life, the special effects are tacky like when Spock has to rescue Kirk on a jet pack when he falls down from a mountain.   Prediction=> 0
# Also there are combos like a burger, fries, and beer for 23 which is a decent deal. Prediction=> 0
# Good price. Prediction=> 1
# I also decided not to send it back because our waitress looked like she was on the verge of having a heart attack. Prediction=> 0
# Anyways, The food was definitely not filling at all, and for the price you pay you should expect more. Prediction=> 1
# 2 Thumbs Up!! Prediction=> 1
# I hate those things as much as cheap quality black olives. Prediction=> 0
# I wear glasses and it fits fine with them. Prediction=> 1
# But other than that the movie seemed to drag and the heroes didn't really work for their freedom.   Prediction=> 0
# The dialogue is composed of things that make little sense.   Prediction=> 0
# I really like this product over the Motorola because it is allot clearer on the ear piece and the mic. Prediction=> 0
# Hard to judge whether these sides were good because we were grossed out by the melted styrofoam and didn't want to eat it for fear of getting sick. Prediction=> 0
# Very wind-resistant. Prediction=> 0
# Food was good, service was good, Prices were good. Prediction=> 1
# It failed to convey the broad sweep of landscapes that were a great part of the original.   Prediction=> 1
# Lousy product. Prediction=> 0
# None of the three sizes they sent with the headset would stay in my ears. Prediction=> 1
# It even has its sweet moments.   Prediction=> 1
# The flair bartenders are absolutely amazing! Prediction=> 1
# The file browser offers all the options that one needs.Handsfree is great. Prediction=> 1
# Their rotating beers on tap is also a highlight of this place. Prediction=> 1
# You can't beat that. Prediction=> 0
# Just reading on the specs alone makes you say WOW. Prediction=> 1
# Your staff spends more time talking to themselves than me. Prediction=> 0
# I was VERY disappointed!! Prediction=> 0
# The only good thing was our waiter, he was very helpful and kept the bloddy mary's coming. Prediction=> 0
# Bland and flavorless is a good way of describing the barely tepid meat. Prediction=> 0
# The point is the journey, a journey that touches every member of the family.   Prediction=> 1
# The rest of the cast also play well.   Prediction=> 1
# I don't recommend unless your car breaks down in front of it and you are starving. Prediction=> 0
# You will leave the theater wanting to go out and dance under the stars.   Prediction=> 0
# I don't think you will be disappointed.   Prediction=> 0
# This review is long overdue, since I consider A Tale of Two Sisters to be the single greatest film ever made.   Prediction=> 1
# Poor quality. Prediction=> 0
# The BT headset was such a disapoinment. Prediction=> 1
# Having trouble with volume. Prediction=> 0
# I rather enjoyed it.   Prediction=> 1
# Waited and waited and waited. Prediction=> 0
# Dee Snider just plain sucks.   Prediction=> 0
# The script is bad, very bad  it contains both cheesiness and unethical joke that you normally see in rated R or NC-17 movie.   Prediction=> 0
# The menu had so much good stuff on it i could not decide! Prediction=> 1
# it did not work in my cell phone plug i am very up set with the charger!. Prediction=> 0
# I thought it was bad.   Prediction=> 0
# there is no real plot.   Prediction=> 0
#  The structure of this film is easily the most tightly constructed in the history of cinema.   Prediction=> 1
# Best Buffet in town, for the price you cannot beat it. Prediction=> 1
# We'd definitely go back here again. Prediction=> 1
# I was particularly pleased with the acting ability of Dwight Schultz.   Prediction=> 1
# The worst, sappiest dialogue... I could go on and on.   Prediction=> 0
# The phone can also take great pictures and even video clips. Prediction=> 1
# He deserves 5 stars. Prediction=> 0
# I hope this place sticks around. Prediction=> 0
# The construction of the headsets is poor. Prediction=> 0
# What a big waste of time. Prediction=> 0
# The only thing that I think could improve is the sound leaks out from the headset. Prediction=> 0
# I was proven dead wrong by this sushi bar, not only because the quality is great, but the service is fast and the food, impeccable. Prediction=> 1
# It didn't make me scared, horrified, or make me sympathetic towards the characters; it was simply annoying.   Prediction=> 0
# Sadly, Gordon Ramsey's Steak is a place we shall sharply avoid during our next trip to Vegas. Prediction=> 1
# It is a really good show to watch.   Prediction=> 1
# Buttons are too small. Prediction=> 1
# My father has the V265, and the battery is dying. Prediction=> 0
# I love being able to use one headset for both by land-line and cell. Prediction=> 1
# Very, very sad. Prediction=> 0
# Not only did it only confirm that the film would be unfunny and generic, but it also managed to give away the ENTIRE movie; and I'm not exaggerating - every moment, every plot point, every joke is told in the trailer.   Prediction=> 0
# There were several moments in the movie that just didn't need to be there and were excruciatingly slow moving.   Prediction=> 1
# Someone shouldve invented this sooner. Prediction=> 1
# Not frightening in the least, and barely comprehensible.   Prediction=> 0
# Appetite instantly gone. Prediction=> 0
# These were so good we ordered them twice. Prediction=> 1
# He is one of my favourite directors, and one of the most talented directors in the history of cinema.   Prediction=> 1
# The story is beyond stupid.   Prediction=> 0
# On the negative, it's insipid enough to cause regret for another 2 hours of life wasted in front of the screen.   Prediction=> 0
# The WORST EXPERIENCE EVER. Prediction=> 0
# Very unreliable service from T-mobile ! Prediction=> 0
# Fantastic service here. Prediction=> 1
# The steak was amazing...rge fillet relleno was the best seafood plate i have ever had! Prediction=> 1
# Audio Quality is poor, very poor. Prediction=> 0
# Secondly, Hitchcock pretty much perfected the thriller and chase movie.   Prediction=> 1
# I even dropped this phone into a stream and it was submerged for 15 seconds and it still works great! Prediction=> 1
# The story line is just awful!   Prediction=> 0
# The rest of the movie lacks art, charm, meaning... If it's about emptiness, it works I guess because it's empty.   Prediction=> 0
# Funny, clever, hip - just like Pray's previous film, Hype!   Prediction=> 1
# It's very convenient and simple to use - gets job done & makes the car ride so much smoother. Prediction=> 1
# 5 stars for the brick oven bread app! Prediction=> 1
# Truly awful. Prediction=> 0
# One more thing: I can tolerate political incorrectness very well, I'm all for artistic freedom and suspension of disbelief, but the Slavic female character was just too much.   Prediction=> 1
# The scripting of the subtle comedy is unmatched by any movie in recent years.   Prediction=> 0
# The explosion of the Gas tanks at the end was just as awful.   Prediction=> 0
# I'm not sure how long we stood there but it was long enough for me to begin to feel awkwardly out of place. Prediction=> 0
# I do think Tom Hanks is a good actor.   Prediction=> 1
# The loudspeaker option is great, the bumpers with the lights is very ... appealing. Prediction=> 1
# The writer, Gorman Bechard, undoubtedly did his homework because all references are industry and character-age appropriate.   Prediction=> 1
# You can't beat the price on these. Prediction=> 1
# Cheap but hey it works.. Was pleasantly suprised given the low cost of this item. Prediction=> 0
# Also the music by Mark Snow is possibly the best score I've ever heard.   Prediction=> 1
# Looks great and is strong." Prediction=> 1
# What a mistake. Prediction=> 0
# The puppets look really cheesy , not in a good way like in the Puppet Master 80's flicks.   Prediction=> 0
# It handles some tough issues with dignity and grace, and, of course, has (shocking spoiler here!   Prediction=> 0
# The chicken wings contained the driest chicken meat I have ever eaten. Prediction=> 0
# I have a Verizon LG phone and they work well together, good reception and range that exceeds 20 feet line of sight. Prediction=> 1
# The keyboard is really worthwhile in usefulness and is sturdy enough I don't expect any problems. Prediction=> 1
# And generally the lines and plot is weaker than the average episode.   Prediction=> 0
# The cocktails are all handmade and delicious. Prediction=> 1
# disappointed. Prediction=> 0
# I have to jiggle the plug to get it to line up right to get decent volume. Prediction=> 0
# The kids play area is NASTY! Prediction=> 0
# I love my 350 headset.. My Jabra350 bluetooth headset is great, the reception is very good and the ear piece is a comfortable fit. Prediction=> 1
# Five star Plus, plus. Prediction=> 1
# The only suspense I was feeling was the frustration at just how retarded the girls were.   Prediction=> 0
# AFTER ARGUING WITH VERIZON REGARDING THE DROPPED CALLS WE RETURNED THE PHONES AFTER TWO DAYS. Prediction=> 0
# Crostini that came with the salad was stale. Prediction=> 0
# DO NOT BUY DO NOT BUYIT SUCKS Prediction=> 0
# Everyone is very attentive, providing excellent customer service. Prediction=> 1
# Good case!. Prediction=> 1
# Comfortable in my hand. Prediction=> 1
# For people who are first timers in film making, I think they did an excellent job!!   Prediction=> 1
# I paid the bill but did not tip because I felt the server did a terrible job. Prediction=> 0
# The reception has been generally good. Prediction=> 1
# The steaks are all well trimmed and also perfectly cooked. Prediction=> 1
# Totally believable.   Prediction=> 0
# It holds a charge for a long time, is reasonably comfortable under long-wearing conditions and the quality of sound is tremendous. Prediction=> 1
# You can find better movies at youtube.   Prediction=> 1
# This is one I did not have, but I watched it recently on Fox Movie Channel, and was very disappointed.   Prediction=> 0
# The plot - well, I said I'd let that one go.   Prediction=> 0
# Plantronics Bluetooth Excelent Buy. Prediction=> 0
# The writers were smack on and I think the best actors and actresses were a bonus to the show.These characters were so real.   Prediction=> 0
# The best phone in market :). Prediction=> 1
# I was so insulted. Prediction=> 0
# I have yet to run this new battery below two bars and that's three days without charging. Prediction=> 0
# This is definitely one of the better documentaries I have seen looking at family relationships and marriage.   Prediction=> 0
# As for the service, I thought it was good. Prediction=> 1
# Very true to Shakespear, and a 'must' for all Shakespear fans.   Prediction=> 1
# Yet, I enjoy watching it.   Prediction=> 1
# The film deserves strong kudos for taking this stand, for having exceptional acting from its mostly lesser-known cast and for the super-intelligent script that doesn't insult the audience or take the easy way out when it comes to white racism.   Prediction=> 0
# Great Phone. Prediction=> 1
# Reversible plug works great. Prediction=> 1
# Reaching for the bottom row is uncomfortable, and the send and end keys are not where I expect them to be.3. Prediction=> 0
# The acting was bad.   Prediction=> 0
# I am also very happy with the price. Prediction=> 1
# So bad...well...it's just bad.   Prediction=> 0
# great...no problems at all!. Prediction=> 1
# The worst phone I've ever had.... Only had it for a few months. Prediction=> 0
# Google mediocre and I imagine Smashburger will pop up. Prediction=> 0
# Everything was perfect the night we were in. Prediction=> 1
# The dialogue is atrocious.   Prediction=> 0
# Poor Reliability. Prediction=> 0
# It was just too horrible.   Prediction=> 0
# Echo Problem....Very unsatisfactory Prediction=> 0
# I have been very satisfied with this cell phone from day one. Prediction=> 1
# There is really nothing for me at postinos, hope your experience is better Prediction=> 0
# Just as good as when I had it more than a year ago! Prediction=> 1
# The restaurant is very clean and has a family restaurant feel to it. Prediction=> 1
# Couldn't figure it out Prediction=> 0
# Great brunch spot. Prediction=> 1
# As for the service: I'm a fan, because it's quick and you're being served by some nice folks. Prediction=> 1
# I would avoid this place if you are staying in the Mirage. Prediction=> 0
# I love Lane, but I've never seen her in a movie this lousy.   Prediction=> 1
# I bought this battery with a coupon from Amazon and I'm very happy with my purchase. Prediction=> 0
# I found this product to be waaay too big. Prediction=> 1
# Not sure who was more lost - the flat characters or the audience, nearly half of whom walked out.   Prediction=> 0
# The best example of how dumb the writing is when it's established that you can turn the zombie-students back into humans by removing a necklace containing a piece of the meteorite.   Prediction=> 0
# Her lines seem to have been WRITTEN by a fifteen year old, though they are trying oh so, so hard to sound like how a fifteen year old would really, um, you know, well... talk.   Prediction=> 0
# It rocked my world and is certainly a must see for anyone with no social or physical outlets.   Prediction=> 1
# The owners are super friendly and the staff is courteous. Prediction=> 1
# I like the fact that it rests lightly against your ear, rather than inside. Prediction=> 1
# I wouldn't say they're worth 2 hours of your time, though.   Prediction=> 0
# As many people complained, I found this headset's microphone was very weak. Prediction=> 1
# If you see it, you should probably just leave it on the shelf.   Prediction=> 0
# Punishment Park is a brilliant piece of cinema.   Prediction=> 0
# What I really like there is the crepe station. Prediction=> 1
# Awful service. Prediction=> 0
# That's a huge design flaw (unless I'm not using it correctly, which I don't think is the case). Prediction=> 1
# I certainly do not mean this distinction in a good way.   Prediction=> 1
# This is a great restaurant at the Mandalay Bay. Prediction=> 1
# I never walked out of a movie faster.   Prediction=> 0
#  I love it.   Prediction=> 1
# So we went to Tigerlilly and had a fantastic afternoon! Prediction=> 1
# Excellent Phone. Prediction=> 1
# I had always known that Errol Flynn was a brilliant actor as he was my dads favourite actor, and I grew up watching his films as a child.   Prediction=> 1
# if you simply want a small flip phone -- look elsewhere as the extra bells & whistles are mediocre. Prediction=> 1
# Great product for the price!. Prediction=> 1
# 10/10   Prediction=> 1
# This product is great... it makes working a lot easier I can go to the copier while waiting on hold for something. Prediction=> 1
# OMG, the food was delicioso! Prediction=> 1
# This is not movie-making.   Prediction=> 1
# Even Billy Bob couldn't rise above the script, which was worse.   Prediction=> 0
# If you have several dozen or several hundred contacts, then imagine the fun of sending each of them one by one. Prediction=> 1
# If you do go see this movie, bring a pillow or a girlfriend/boyfriend to keep you occupied through out.   Prediction=> 1
# But when someone strives for greatness and poetry, but delivers a muddled (and often ridiculous) story, a bunch of disparate scenes, pretentious dialogue... Then you get the worst kind of a movie that some other reviewer very accurately defined as pretentious crap".   Prediction=> 0
# Yes, I am simplifying things here for the sake of brevity, for this really is at the core of the problems with this film - it has too much going on without any real, fulfilling explanation.   Prediction=> 0
# Whatever the producer was going for, he missed entirely.   Prediction=> 1
# If you want a real scare rent this one!   Prediction=> 0
# I don't think I've ever seen a movie half as boring as this self-indulgent piece of junk.   Prediction=> 0
# I can't use this case because the smell is disgusting. Prediction=> 0
# The success of the film depends on the casting of Sydney Greenstreet as the Alexander Yardley character.   Prediction=> 1
# I'm still trying to get over how bad it was.   Prediction=> 0
# Bad day or not, I have a very low tolerance for rude customer service people, it is your job to be nice and polite, wash dishes otherwise!! Prediction=> 1
# The roast beef sandwich tasted really good! Prediction=> 0
# Good case, Excellent value. Prediction=> 1
# But above all the exquisite visual composition of each moment, with inventive and elegant use of close-up, camera angle and lighting, including pointillistic faux home movie footage, is a wonder and joy to behold.   Prediction=> 1
# The cast of veteran actors are more than just a nostalgia trip.   Prediction=> 1
# Still, it was the SETS that got a big 10 on my oy-vey scale.   Prediction=> 1
# I think that it is a must see older John Wayne film.   Prediction=> 0
# The design is very odd, as the ear clip is not very comfortable at all. Prediction=> 1
# Omit watching this.   Prediction=> 1
# I agree with Jessica, this movie is pretty bad.   Prediction=> 0
# The staff is great, the food is delish, and they have an incredible beer selection. Prediction=> 1
# My husband said she was very rude... did not even apologize for the bad food or anything. Prediction=> 0
# Freezes frequently4. Prediction=> 0
# This is essentially a communications tool that does not communicate. Prediction=> 0
# This is a witty and delightful adaptation of the Dr Seuss book, brilliantly animated by UPA's finest and thoroughly deserving of its Academy Award.   Prediction=> 1
# The kids are very cool too.   Prediction=> 1
# Works great. Prediction=> 1
# I swung in to give them a try but was deeply disappointed. Prediction=> 0
# Trying to make a call on these is an exercise in frustration. Prediction=> 0
# Will not be back. Prediction=> 0
# Works as described. Prediction=> 0
# I know that sounds funny, but to me it seemed like sketchy technology that wouldn't work well.Well, this one works great. Prediction=> 1
# I have purchased these for both family and friends, and all enjoy their clarity and ease of use Prediction=> 1
# I personally love the hummus, pita, baklava, falafels and Baba Ganoush (it's amazing what they do with eggplant!). Prediction=> 1
# If it was to turn my good day feeling into a night of disturbing memories than I guess he succeeded.   Prediction=> 0
# And considering the two of us left there very full and happy for about $20, you just can't go wrong. Prediction=> 0
# Don't buy this product. Prediction=> 0
# I didn't know pulled pork could be soooo delicious. Prediction=> 1
# The Burrittos Blah! Prediction=> 0
# I have never had such bland food which surprised me considering the article we read focused so much on their spices and flavor. Prediction=> 0
# Would not recommend to others. Prediction=> 1
# All of the tapas dishes were delicious! Prediction=> 1
# I am very impressed with this headset from Plantronics. Prediction=> 0
# Today was my first taste of a Buldogis Gourmet Hot Dog and I have to tell you it was more than I ever thought possible. Prediction=> 0
# It lacked flavor, seemed undercooked, and dry. Prediction=> 0
# It dit not work most of the time with my Nokia 5320. Prediction=> 0
# Don't do it!!!! Prediction=> 0
# Total brunch fail. Prediction=> 0
# Alexander Nevsky is a great film.   Prediction=> 1
# Do NOT buy if you want to use the holster. Prediction=> 0
# Due to this happening on every call I was forced to stop using this headset. Prediction=> 0
# Excellent product for the price. Prediction=> 1
# I won't say any more - I don't like spoilers, so I don't want to be one, but I believe this film is worth your time.   Prediction=> 0
# I even fully charged it before I went to bed and turned off blue tooth and wi-fi and noticed that it only had 20 % left in the morning. Prediction=> 0
# And there wasn't a single sour note struck acting-wise, either; some surprisingly solid casting, here.   Prediction=> 1
# I didn't realize how wonderful the short really is until the last two scenes.   Prediction=> 1
# The only place good for this film is in the garbage.   Prediction=> 1
# It was a waste of my money. Prediction=> 0
# Spend your money elsewhere. Prediction=> 0
# There is a lot of beautiful places.   Prediction=> 1
# for 40 bucks a head, i really expect better food. Prediction=> 1
# Always a great time at Dos Gringos! Prediction=> 1
# The eargels channel the sound directly into your ear and seem to increase the sound volume and clarity. Prediction=> 1
# How can that be?The audio quality is poor. Prediction=> 0
# I gave it 5 stars then, and I'm giving it 5 stars now. Prediction=> 1
# This particular model would not work with my Motorola Q smartphone. Prediction=> 0
# Excellent wallet type phone case. Prediction=> 1
# I believe the screenwriter did a good job of tying up the loose ends.   Prediction=> 1
# The vegetables are so fresh and the sauce feels like authentic Thai. Prediction=> 0
# Ursula Burton's portrayal of the nun is both touching and funny at the same time with out making fun of nuns or the church.   Prediction=> 1
# He can't act (one of the least scary villains I have ever seen), he can't write (did he write this damn movie in his sleep?   Prediction=> 0
# Linked to my phone without effort. Prediction=> 1
# I thoroughly enjoyed it when Christopher Eccleston took control of the TARDIS and the continuation of the series.   Prediction=> 1
# It has been a winner for us. Prediction=> 1
# Worst food/service I've had in a while. Prediction=> 0
# To my disbelief, each dish qualified as the worst version of these foods I have ever tasted. Prediction=> 0
# The ripped banana was not only ripped, but petrified and tasteless. Prediction=> 0
# If there was ever an indication of a writer and a director's ability to meld two highly volatile temperaments into a seamless union of creativity, then this is it!   Prediction=> 1
# The story unfolds in 18th century Jutland and the use of period music played on period instruments is just one more fine touch.   Prediction=> 1
# It seems completely secure, both holding on to my belt, and keeping the iPhone inside. Prediction=> 1
# Won't go back. Prediction=> 0
# You wont regret it!   Prediction=> 1
# My salad had a bland vinegrette on the baby greens and hearts of Palm. Prediction=> 0
# It works great with a car charger, especially if you cannot plug in two adapters at the same time. Prediction=> 0
# Nice Sound. Prediction=> 1
# Rip off---- Over charge shipping. Prediction=> 0
# This place receives stars for their APPETIZERS!!! Prediction=> 0
# It had some average acting from the main person, and it was a low budget as you clearly can see.   Prediction=> 0
# No one at the table thought the food was above average or worth the wait that we had for it. Prediction=> 0
# It does everything the description said it would. Prediction=> 0
# The character developments also lacked in depth.   Prediction=> 0
# An Awesome New Look For Fall 2000!. Prediction=> 1
# The only consistent thread holding the series together were the amazing performances of Leni Parker and Anita LaSelva as the two Taelons in quiet idealogical conflict.   Prediction=> 1
# I purcashed this for the car charger and it does not work. Prediction=> 0
# Just really good.. So far, probably the best BT headset I have ever had. Prediction=> 1
# Things happen, characters personalities change, plot twists occur for no real reason other than that script calls for it.   Prediction=> 0
# Even in my BMW 3 series which is fairly quiet, I have trouble hearing what the other person is saying. Prediction=> 0
# Very disappointing.   Prediction=> 0
# Doesn't do the job. Prediction=> 1
# It has everything I need and I couldn't ask for more. Prediction=> 1
# Lots of holes in the script.   Prediction=> 0
# The entire audience applauded at the conclusion of the film.   Prediction=> 1
# Watching washing machine twirling around wouldn't hurt your eyes as much as this show.   Prediction=> 1
# Bacon is hella salty. Prediction=> 1
# IT'S REALLY EASY. Prediction=> 1
# Restored my phone to like new performance. Prediction=> 1
# Everything about it is fine and reasonable for the price i.e. Prediction=> 1
# The nachos are a MUST HAVE! Prediction=> 0
# Talk about great customer service of course we will be back. Prediction=> 1
# If you haven't gone here GO NOW! Prediction=> 0
# Disappointment.. I hate anything that goes in my ear. Prediction=> 0
# Thank you for such great service. Prediction=> 1
# The food, amazing. Prediction=> 1
# Service was very prompt. Prediction=> 1
# ), and sometimes it was so embarrassing that I had to look away.   Prediction=> 0
# Which are small and not worth the price. Prediction=> 1
# Muddy, low quality sound, and the casing around the wire's insert was poorly super glued and slid off. Prediction=> 1
# The memories are murky but I can only say that I enjoyed every single episode and product related to the show.   Prediction=> 1
# Plan on ordering from them again and again. Prediction=> 0
# Not good for the money. Prediction=> 1
# Unfortunately, 'Cover Girl' is an example of how Hollywood used to exploit women for financial gain.   Prediction=> 0
# Yeah, the movie pretty much sucked.   Prediction=> 0
# It felt too light and tinny.". Prediction=> 1
# I was totally fascinated by the music, the dancing... everything.   Prediction=> 0
# VERY funny!   Prediction=> 1
# This is a bad film, with bad writing, and good actors....an ugly cartoon crafted by Paul Haggis for people who can't handle anything but the bold strokes in storytelling....a picture painted with crayons.   Prediction=> 0
# I took back my money and got outta there. Prediction=> 0
# In short, don't bother with this movie.   Prediction=> 0
# Excellent short film.   Prediction=> 1
# A PIECE OF JUNK THAT BROKE AFTER BEING ON MY PHONE FOR 2 DAYS!!! Prediction=> 0
# This is a very right on case movie that delivers everything almost right in your face.   Prediction=> 1
# 2 thumbs up to this seller Prediction=> 1
# don't waste your money. Prediction=> 0
# I bought this phone as a replacement for my StarTac and have regretted it since. Prediction=> 0
# Last time buying from you. Prediction=> 0
# Battery is terrible. Prediction=> 0
# The best scene in the movie was when Gerardo is trying to find a song that keeps running through his head.   Prediction=> 1
# The plot, such as it is, is so derivative and predictable that the ending is like a mercy killing.   Prediction=> 1
# This is definitely one of the bad ones.   Prediction=> 0
# For the price this was a great deal. Prediction=> 1
# Product is exactly as described. Prediction=> 0
# Works well. Prediction=> 1
# The worst was the salmon sashimi. Prediction=> 0
# If you act in such a film, you should be glad that you're gonna drift away from earth as far as possible!   Prediction=> 0
# I have recommended it to friends.   Prediction=> 1
# i wouldnt see this movie again for free.   Prediction=> 0
# I have always used corded headsets and the freedom from the wireless is very helpful. Prediction=> 1
# Never been to Hard Rock Casino before, WILL NEVER EVER STEP FORWARD IN IT AGAIN! Prediction=> 1
# Exceptionally bad!   Prediction=> 0
# The service was a bit lacking. Prediction=> 0
# Gave up trying to eat any of the crust (teeth still sore). Prediction=> 0
# All in all, I'm quite satisfied with this purchase. Prediction=> 0
# The waitress and manager are so friendly. Prediction=> 1
# Excellent starter wireless headset. Prediction=> 1
# I had the opportunity today to sample your amazing pizzas! Prediction=> 1
# The casting is also horrible, cause all you see is a really really BAD Actors, period.   Prediction=> 0
# I hate writing bad reviews about films - especially those in which I really like the star - but this film is so bad I don't believe for one second that anyone could have been proud of it.   Prediction=> 0
# The pairing of the two devices was so easy it barely took a couple minutes before I started making calls with the voice dialing feature. Prediction=> 0
# Stopped by this place while in Madison for the Ironman, very friendly, kind staff. Prediction=> 1
# The use of slow-motion needlessly repeats itself throughout the movie but is well backed up by bad acting (and bad is a kind word here), no continuity, scenes that are thrown in for no reason whatsoever, vehicles that looked like they were made from a Corn Flakes box and a directorial style that bordered on stupidity.   Prediction=> 0
# The acting is like watching wooden puppets moving around and reading from a book, that's how bad it is.   Prediction=> 0
# I Was Hoping for More. Prediction=> 0
# Emily Watson's character is very strong, and she has only to give a quick glance and you understand everything.   Prediction=> 0
# The telephone repair man was really funny and his reactions to the nuts and bitchy boss were truly genuine.   Prediction=> 1
# This is a good battery, and it got here really fast. Prediction=> 1
# The sweet potato fries were very good and seasoned well. Prediction=> 1
# If you want healthy authentic or ethic food, try this place. Prediction=> 0
# This if the first movie I've given a 10 to in years.   Prediction=> 1
# Great food and great service in a clean and friendly setting. Prediction=> 1
# Although I very much liked the look and sound of this place, the actual experience was a bit disappointing. Prediction=> 0
# They work about 2 weeks then break. Prediction=> 0
# Overall, I don't think that I would take my parents to this place again because they made most of the similar complaints that I silently felt too. Prediction=> 1
# I had a seriously solid breakfast here. Prediction=> 1
# We won't be returning. Prediction=> 0
# New Battery works great in phone. Prediction=> 1
# No buyers remorse on this one!. Prediction=> 0
# The poor batter to meat ratio made the chicken tenders very unsatisfying. Prediction=> 0
# The classic Maine Lobster Roll was fantastic. Prediction=> 1
# Very bad Experience! Prediction=> 0
# Don't bother coming here. Prediction=> 0
# ) What makes this story different are the terrific production values - faultless photography, composition and editing - the terrific casting - the underappreciated Brian Keith playing a bully Teddy - and vivid history.   Prediction=> 1
# The characters are interesting, even if a bit predictable.   Prediction=> 0
# I only hear garbage for audio. Prediction=> 0
# I've missed numerous calls because of this reason. Prediction=> 1
# This movie is excellent!Angel is beautiful and Scamp is adorable!His little yelps when hes scared,and the funniest parts are when:Scamp is caught under the curtain and when Angel and Scamp are singing 'Ive Never Had This Feeling Before'.I totally recommend this movie,its coming out on special edition on June 20.The cover has scamp on a garbage can and Angel underneath the lid.   Prediction=> 0
# The camera on the phone may be used as a dustpan when indoors... I'd rather be using a disposable then this. Prediction=> 1
# This place is overpriced, not consistent with their boba, and it really is OVERPRICED! Prediction=> 0
# Waste your money on this game.   Prediction=> 0
# The plot simply rumbles on like a machine, desperately depending on the addition of new scenes.   Prediction=> 0
# Great food and service, huge portions and they give a military discount. Prediction=> 1
# If you plan to use this in a car forget about it. Prediction=> 1
# I'll put this gem up against any movie in terms of screenplay, cinematography, acting, post-production, editing, directing, or any other aspect of film-making.   Prediction=> 0
# Avoid this one if you can. Prediction=> 0
# the only VERY DISAPPOINTING thing was there was NO SPEAKERPHONE!!!! Prediction=> 0
# I love this device. Prediction=> 1
# I am more than happy with this product. Prediction=> 1
# But now that it is out of warranty the same problems reoccure.Bottom line... put your money somewhere else... Cingular will not support it. Prediction=> 0
# The warm beer didn't help. Prediction=> 1
# The battery works great! Prediction=> 1
# Jamie Foxx absolutely IS Ray Charles.   Prediction=> 1
# This wonderful experience made this place a must-stop whenever we are in town again. Prediction=> 1
# There was so much hype over this phone that I assumed it was the best, my mistake. Prediction=> 0
# Big Disappointment with calendar sync. Prediction=> 0
# in addition it feels &amp; looks as if the phone is all lightweight cheap plastic. Prediction=> 0
# Excellent hands free tool. Prediction=> 1
# I love their fries and their beans. Prediction=> 1
# i got this phone around the end of may and i'm completely unhappy with it. Prediction=> 0
# All in all I think it was a good investment. Prediction=> 1
# They have been around for years and carries the highest quality of anti-glare screen protector that I have found to date. Prediction=> 1
# Then a few days later the a puff of smoke came out of the phone while in use. Prediction=> 1
# this place is good. Prediction=> 1
# The two main characters may be two of the most believable children I ever saw put on screen.   Prediction=> 1
# Is it possible for a movie to get any worse than this?   Prediction=> 0
# The food was outstanding and the prices were very reasonable. Prediction=> 1
# Design Flaw?. Prediction=> 0
# Jimmy Stewart is as ever a great hero for Hitchcock, the story rips along to its cool climax at an embassy function, but it lacks the brooding menace of Hitchcock's black and white, low-budget original.   Prediction=> 1
# Okay, I like to consider myself a fair critic, so I'll give credit where credit's due--the creature effects were actually pretty cool.   Prediction=> 1
# -My order was not correct. Prediction=> 0
# Avoid at any and all costs.   Prediction=> 0
# Worst ever. Prediction=> 0
# Last night was my second time dining here and I was so happy I decided to go back! Prediction=> 0
# This place is not quality sushi, it is not a quality restaurant. Prediction=> 1
# My ribeye steak was cooked perfectly and had great mesquite flavor. Prediction=> 1
# How awesome is that. Prediction=> 1
# I'd say that would be the hardest decision... Honestly, all of M's dishes taste how they are supposed to taste (amazing). Prediction=> 0
# I think not again Prediction=> 0
# Host staff were, for lack of a better word, BITCHES! Prediction=> 0
# Do yourself a favor and stay away from this dish. Prediction=> 0
# Lucy Bell is so much higher than this crap and for her to sink this low is quite depressing.   Prediction=> 0
# Unreliable - I'm giving up. Prediction=> 0
# Unfortunately, this is a bad movie that is just plain bad.   Prediction=> 0
# The cashier had no care what so ever on what I had to say it still ended up being wayyy overpriced. Prediction=> 1
# It didn't work, people can not hear me when I talk. Prediction=> 0
# You need at least 3 mins to get to your phone book from the time you first turn on the phone.Battery life is short. Prediction=> 0
# I do love sushi, but I found Kabuki to be over-priced, over-hip and under-services. Prediction=> 1
# What a great double cheeseburger! Prediction=> 1
# Raw and sublimely moving.   Prediction=> 0
# Case was more or less an extra that I originally put on but later discarded because it scratched my ear. Prediction=> 1
# I think this restaurant suffers from not trying hard enough. Prediction=> 0
# The fried rice was dry as well. Prediction=> 0
# Lifetime does not air it enough, so if anyone knows what store sells it let me know because this is a must-have.   Prediction=> 0
# It sure does beat the nachos at the movies but I would expect a little bit more coming from a restaurant. Prediction=> 0
# The nokia CA-42 USB cable did not work with my phone. Prediction=> 0
# This fixes all the problems. Prediction=> 0
# And, quite honestly, often its not very good.   Prediction=> 1
# You need two hands to operate the screen.This software interface is decade old and cannot compete with new software designs. Prediction=> 1
# I've had this for nearly 2 years and it has worked great for me. Prediction=> 1
# The lines, the cuts, the audio, everything is wrong.   Prediction=> 0
# Great place to have a couple drinks and watch any and all sporting events as the walls are covered with TV's. Prediction=> 1
# the cast was great.   Prediction=> 1
# Att is not clear, sound is very distorted and you have to yell when you talk. Prediction=> 1
# After charging overnight, these batteries work great. Prediction=> 1
# The mic is great. Prediction=> 1
#  But Storm Trooper is not even bad enough to make it to the list of wonderfully terrible movies.   Prediction=> 0
# On the good side, the staff was genuinely pleasant and enthusiastic - a real treat. Prediction=> 1
# It's PURE BRILLIANCE.   Prediction=> 1
# I didn't think that the instructions provided were helpful to me. Prediction=> 0
# I highly doubt that anyone could ever like this trash.   Prediction=> 0
# I always order from the vegetarian menu during dinner, which has a wide array of options to choose from. Prediction=> 1
# Much less than the jawbone I was going to replace it with. Prediction=> 0
# The best place in Vegas for breakfast (just check out a Sat, or Sun. Prediction=> 1
# I mean, in a realistic world, she would NEVER have gotten into that ballet repertory... The whole thing was quite pathetic.   Prediction=> 0
# He really didn't seem to want to be hosting; his voice-overs were monotonous, didn't get involved with the guests.   Prediction=> 1
# I just got bored watching Jessice Lange take her clothes off!   Prediction=> 0
# A truly, truly bad film.   Prediction=> 0
# I never come again. Prediction=> 0
# I just don't know how this place managed to served the blandest food I have ever eaten when they are preparing Indian cuisine. Prediction=> 0
# O my gosh the best phone I have ever had. Prediction=> 1
# Woa, talk about awful.   Prediction=> 0
# The jerky camera movements were also annoying.   Prediction=> 0
# I really enjoyed Crema Café before they expanded; I even told friends they had the BEST breakfast. Prediction=> 0
# All in all a beautiful directed film from Nicola's roeg wih a sublime cast.   Prediction=> 1
# doesn't last long. Prediction=> 0
# From what my dinner companions told me...everything was very fresh with nice texture and taste. Prediction=> 0
# The acting, as you'd expect from this cast, is top notch.   Prediction=> 1
# It's practically perfect in all of them  a true masterpiece in a sea of faux masterpieces.   Prediction=> 1
# I was shocked because no signs indicate cash only. Prediction=> 0
# I really hope the team behind this movie makes more movies, and that they will continue to do so in their own, some kinda weird style.   Prediction=> 0
# The stories were as unbelievable as the actors.   Prediction=> 1
# Nice, spicy and tender. Prediction=> 1
# Food was really good and I got full petty fast. Prediction=> 1
# The dialogue sucked.   Prediction=> 0
# Also difficult to put on.I'd recommend avoiding this product. Prediction=> 0
# Oh this is such a thing of beauty, this restaurant. Prediction=> 0
# Good beer & drink selection and good food selection. Prediction=> 1
# Hot dishes are not hot, cold dishes are close to room temp.I watched staff prepare food with BARE HANDS, no gloves.Everything is deep fried in oil. Prediction=> 1
# Mobile Phone Tools are a must have. Prediction=> 1
# It has kept up very well. Prediction=> 1
# By the time the pyromaniac waylaid the assistant I was bored and didn't care what happened next and so I switched off.   Prediction=> 0
# Juano Hernandez (an exceptional actor who played supporting roles in many films of the era) is a proud black man who is accused of murdering a white man in the South.   Prediction=> 1
# this is the worst sushi i have ever eat besides Costco's. Prediction=> 0
# It is super charged up for use as a small hybrid palmtop/camera/cellphone, and excels in those roles. Prediction=> 1
# We got the food and apparently they have never heard of salt and the batter on the fish was chewy. Prediction=> 0
# When I placed my treo into the case, not only was it NOT snug, but there was A LOT of extra room on the sides. Prediction=> 1
# Exactly what I wanted. Prediction=> 1
# STEAMBOAT WILLIE is an amazingly important film to our cinema history.   Prediction=> 1
# Perfect for the PS3. Prediction=> 1
# To call this movie a drama is ridiculous!   Prediction=> 1
# his performance, as awarded, was stunning.   Prediction=> 1
# Saggy, floppy piece of junk. Prediction=> 0
# I have to use the smallest earpieces provided, but it stays on pretty well. Prediction=> 1

# %%
# Accuracy
print("Accuracy: ",pipe.score(X_test,y_test))
print("Accuracy: ",pipe.score(X_test,sample_prediction))
# Out:
# Accuracy:  0.7883333333333333
# Accuracy:  1.0

# %%
# Accuracy
print("Accuracy: ",pipe.score(X_train,y_train))
# Out:
# Accuracy:  0.9774718397997497

# %%
example = ["I do enjoy my job",
 "What a poor product!,I will have to get a new one",
 "I feel amazing!"]

# %%
pipe.predict(example)
# Out:
# array([1, 0, 1], dtype=int64)
