# %% [markdown]
# ### On Anaconda Prompt [RUN AS ADMINISTRATOR]
# #### C:\Users\Lenovo>python -m spacy download en_core_web_sm
# #### C:\Users\Lenovo>python -m spacy download en_core_web_md
# #### C:\Users\Lenovo>python -m spacy download en_core_web_lg

# %% [markdown]
# ### THEORY:
# SOURCE:https://github.com/rahulvaish/ReferenceDocuments/blob/master/QuickGuide%5BIMAGES%5D/MachineLearningQuickGuide%5BIMAGES%5D/Word2VecRepresentation.jpg
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### In Spacy there are 4 English models:
#
# #### [1] n_core_web_sm
# #### [2] en_core_web_md
# #### [3] en_core_web_lg
# #### [4] en_vectors_web_lg
# #### REF: https://spacy.io/models/en

# %%
import spacy
nlp = spacy.load('en_core_web_lg')  #Choosing the larger one - "lg"

# %%
tokens = nlp(u'dog cat banana')

for token1 in tokens:
    for token2 in tokens:
        print(token1.text, token2.text, token1.similarity(token2))
# Out:
# dog dog 1.0
# dog cat 0.80168545
# dog banana 0.24327648
# cat dog 0.80168545
# cat cat 1.0
# cat banana 0.28154367
# banana dog 0.24327648
# banana cat 0.28154367
# banana banana 1.0

# %%
#This loooks just fine.
#But poorly works with examples like below..

# %%
tokens = nlp(u'man brave king and women beautiful queen')

for token1 in tokens:
    for token2 in tokens:
        print(token1.text, token2.text, token1.similarity(token2))
# Out:
# man man 1.0
# man brave 0.4687047
# man king 0.40884617
# man and 0.3440947
# man women 0.45256585
# man beautiful 0.37816587
# man queen 0.27109137
# brave man 0.4687047
# brave brave 1.0
# brave king 0.3280089
# brave and 0.24658339
# brave women 0.3400278
# brave beautiful 0.3714461
# brave queen 0.31917185
# king man 0.40884617
# king brave 0.3280089
# king king 1.0
# king and 0.27538317
# king women 0.1680698
# king beautiful 0.21729226
# king queen 0.72526103
# and man 0.3440947
# and brave 0.24658339
# and king 0.27538317
# and and 1.0
# and women 0.36823362
# and beautiful 0.37451503
# and queen 0.22077888
# women man 0.45256585
# women brave 0.3400278
# women king 0.1680698
# women and 0.36823362
# women women 1.0
# women beautiful 0.33176085
# women queen 0.2862379
# beautiful man 0.37816587
# beautiful brave 0.3714461
# beautiful king 0.21729226
# beautiful and 0.37451503
# beautiful women 0.33176085
# beautiful beautiful 1.0
# beautiful queen 0.3514231
# ...

# %%
tokens = nlp(u'dog and jackal is like cat and lion')

for token1 in tokens:
    for token2 in tokens:
        print(token1.text, token2.text, token1.similarity(token2))
# Out:
# dog dog 1.0
# dog and 0.2966885
# dog jackal 0.24102436
# dog is 0.33961135
# dog like 0.36687168
# dog cat 0.80168545
# dog and 0.2966885
# dog lion 0.47424486
# and dog 0.2966885
# and and 1.0
# and jackal -0.022540377
# and is 0.45814785
# and like 0.5267484
# and cat 0.2383505
# and and 1.0
# and lion 0.19124143
# jackal dog 0.24102436
# jackal and -0.022540377
# jackal jackal 1.0
# jackal is -0.017124852
# jackal like 0.044634186
# jackal cat 0.31780094
# jackal and -0.022540377
# jackal lion 0.5582606
# is dog 0.33961135
# is and 0.45814785
# is jackal -0.017124852
# is is 1.0
# is like 0.454775
# is cat 0.28220233
# is and 0.45814785
# is lion 0.20940298
# like dog 0.36687168
# like and 0.5267484
# like jackal 0.044634186
# like is 0.454775
# like like 1.0
# like cat 0.35981405
# like and 0.5267484
# like lion 0.25614715
# cat dog 0.80168545
# cat and 0.2383505
# cat jackal 0.31780094
# cat is 0.28220233
# cat like 0.35981405
# cat cat 1.0
# cat and 0.2383505
# ...
